# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3.4 오류 역전파 알고리즘

# %% [markdown]
# # 3.41 목적함수의 정의
#
# ## 훈련집합

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 기계 학습의 목표
# - 모든 샘플을 옳게 분류하는 식 함수 f를 찾는 것, y =f(x)
