# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt#하위모듈

# %matplotlib inline

# %%
plt.plot([3,2,3,4,5]) # y= x+1, y값은 리스트에 있는 값, x는 index(0,1,2,3,4)값을 기준으로 자동 생성
plt.show() # plt확인 명령

# %% [markdown]
# # Figsize : figure(도면)의 사이즈 조절

# %%
plt.figure(figsize=(6,6)) # plotting을 할 도면을 선언 , 튜플 형태로 선언한다, 6x6사이즈 = 72x6 72x6 
plt.plot([0,5])

# %% [markdown]
# ## 2차함수 그래프 with piot()

# %%
#리스트를 이용해서 그리면 y=x 형태

#plt.plot([0,100])

# numpy를 이용해서 함수그래프 그리기

x= np.array([1,2,3,4,5]) #정의역
y= np.array([1,4,9,16,25]) # f(x)
plt.plot(x,y)

# %%
np.arange #기존 파이썬 range와 다른점 =  (a,b,c)로 구성, c로 쪼개 줄 수 있다?는 간격을 의미함
x = np.arange(-10,10,0.01)
x[:5]
plt.plot(x,x**2)
#넘파이 데이터도 그래프를 만들 수 있음.

# %%
#x, y축에 설명 추가하기
x = np.arange(-10,10,0.01)

plt.xlabel("x value")
plt.ylabel("f(x) value")

plt.plot(x,x**2)

# %%
#x,y축의 범위를 설정하기, =일부분만 보기!!!!!

x = np.arange(-10,10,0.01)

plt.xlabel("x value")
plt.ylabel("f(x) value")

plt.axis([-5,5,0,25]) #리스트로 값을 넣어줄 수 있음 [x갑 최소, x값 최대, y값 최소, y값 최대]

plt.plot(x,x**2)

# %%
#x,y 축에 눈금 설정하기 xticks

#x,y축의 범위를 설정하기, =일부분만 보기!!!!!

x = np.arange(-10,10,0.01)

plt.xlabel("x value")
plt.ylabel("f(x) value")

plt.axis([-5,5,0,25]) 
plt.xticks ([i for i in range(-5,6,1)])
plt.yticks ([i for i in range(0,27,3)])

plt.plot(x,x**2)

# %%
# 그래프에 title 달기

x = np.arange(-10,10,0.01)

plt.xlabel("x value")
plt.ylabel("f(x) value")
plt.axis([-5,5,0,25]) 
plt.xticks ([i for i in range(-5,6,1)])
plt.yticks ([i for i in range(0,27,3)])

plt.title("y= x^2 graph")


plt.plot(x,x**2, label="trend")#######label 범례 레전드
plt.legend()
plt.show()
