# %% [markdown]
# #  CNN 추가 실습_이미지분류(cat vs dog)

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### (1) 라이브러리 로딩

# %%
import cv2
from google.colab.patches import cv2_imshow

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random as rd
import os

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential, load_model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from keras.backend import clear_session
from keras.optimizers import Adam

# %% [markdown]
# * 함수 만들기

# %%
# 학습곡선 함수
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### (2) 구글드라이브 마운트

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### (3) 원본 데이터 둘러보기
# * 공유받은 폴더 'images'를 자신의 구글드라이브에 업로드 합니다.
# * 업로드 위치 : 내드라이브 바로 아래!

# %% [markdown]
# * 데이터 목록 읽어오기

# %%
path = '//content/drive/MyDrive/딥러닝/학생용/d'

fileList = os.listdir(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-4ddc2a38fc24> in <module>
#       1 path = '//content/drive/MyDrive/딥러닝/학생용/dogs'
#       2
# ----> 3 fileList = os.listdir(path)
#
# FileNotFoundError: [Errno 2] No such file or directory: '//content/drive/MyDrive/딥러닝/학생용/dogs'

# %% [markdown]
# * 이미지 파일 둘러보기
#     * 아래 셀을 반복실행해 봅시다.

# %%
# n = rd.randrange(0, len(fileList))
# fileList[n]
# file_r = path + '/' + fileList[n]
# img = cv2.imread(file_r)
# print(img.shape)
# cv2_imshow(img)

# %% [markdown]
# ## 2.이미지 전처리
#
# * 이미지를 전처리하는 작업은 꽤 오래 걸리는 작업입니다.
# * 아래 절차와 코드가 있지만, 중간 결과물을 이용하여 진행해 보도록 하겠습니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (1) 파일 크기, 흑백 맞춰서 저장하기
# * 흑백이미지
# * 150 * 150 크기

# %% [markdown]
# * 아래 코드는 시간이 많이 소요되므로 이미 수행한 이미지를 사용합니다.
# * 실제 데이터를 가지고 테스트할 때는 전처리를 수행해보게 됩니다.

# %%
# path_r = '/content/drive/MyDrive/images/cats'
# path_w = '/content/drive/MyDrive/images/cats2'
# fileList = os.listdir(path_r)

# for idx, file in enumerate(fileList) :
#     file_r = path_r + '/' + file
#     img = cv2.imread(file_r, cv2.IMREAD_GRAYSCALE)  # 읽을때, 흑백으로 변환
#     img = cv2.resize(img, (150, 150))               # 크기 맞추기
#     file_w = path_w + '/' + str(idx) + '.jpg'
#     cv2.imwrite(file_w, img)                        # cats2에 저장
#     print(idx)

# %%
# path_r = '/content/drive/MyDrive/images/dogs'
# path_w = '/content/drive/MyDrive/images/dogs2'
# fileList = os.listdir(path_r)

# for idx, file in enumerate(fileList) :
#     file_r = path_r + '/' + file
#     img = cv2.imread(file_r, cv2.IMREAD_GRAYSCALE)
#     img = cv2.resize(img, (150, 150))
#     file_w = path_w + '/' + str(idx) + '.jpg'
#     cv2.imwrite(file_w, img)
#     print(idx)

# %% [markdown]
# ### (2) 하나의 데이터셋으로 만들기
# * 약 2 ~ 5분 소요

# %%
# # cat2
# path = '/content/drive/MyDrive/images/cats2/'
# fileList = os.listdir(path)
# cat_file = len(fileList)

# for idx, file in enumerate(fileList) :
#     file_name = path + '/' + file
#     img = cv2.imread(file_name, cv2.IMREAD_GRAYSCALE)
#     if idx == 0 :
#         x = img.reshape(1,150,150)
#     else :
#         x = np.concatenate((x, img.reshape(1,150,150)), axis=0)

# %%
# # dog2
# path = '/content/drive/MyDrive/images/dogs2/'
# fileList = os.listdir(path)
# dog_file = len(fileList)

# for idx, file in enumerate(fileList) :
#     file_name = path + '/' + file
#     img = cv2.imread(file_name, cv2.IMREAD_GRAYSCALE)
#     x = np.concatenate((x, img.reshape(1,150,150)), axis=0)

# y = np.array([0] * cat_file + [1] * dog_file)
# x.shape, y.shape

# %% [markdown]
# * [추가] 만약 데이터셋으로 저장하는 데 시간이 오래 걸리거나, 잘 안된다면 아래 코드를 실행해주세요.

# %%
import joblib # 파이썬으로 만든 오브젝트를 저장하거나 로딩할 수 있는 라이브러리.

# 여러분의 구글 경로
path = "/content/drive/MyDrive/딥러닝/학생용/"

# 로딩하기
x_filename = path + 'x_catdog6000.pkl'
y_filename = path + 'y_catdog6000.pkl'

x = joblib.load(x_filename) 
y = joblib.load(y_filename)

x.shape, y.shape
# Out:
# ((6000, 150, 150), (6000,))

# %% [markdown]
# * 전처리된 데이터 사진 둘러보기

# %%
n = 100
cv2_imshow(x[n])
# Out:
# <PIL.Image.Image image mode=L size=150x150 at 0x7F43447067F0>

# %% [markdown]
# ## 3.모델링

# %% [markdown]
# ### (1) 데이터 전처리

# %% [markdown]
# * 데이터 분할

# %%
x_train, x_val, y_train, y_val = train_test_split(x,y, test_size = 2000)
x_train.shape, x_val.shape
# Out:
# ((4000, 150, 150), (2000, 150, 150))

# %% [markdown]
# * 모델 입력(input_shape)에 맞게 차원 조절

# %%
x_train = x_train.reshape(-1, 150, 150, 1) #4차원으로
x_val = x_val.reshape(-1, 150, 150, 1)

# %%
x_train.shape, x_val.shape
# Out:
# ((4000, 150, 150, 1), (2000, 150, 150, 1))

# %% [markdown]
# * Scaling : Min-Max
#     * 0-255 값으로 되어 있는 데이터를 0-1사이 값으로 변환
#     * x_train, x_val를 그냥 255로 나누면 됨

# %%
x_train = x_train / 255.
x_val = x_val / 255.

# %% [markdown]
# ### (2) 모델링
# * 아래 구조와 동일하거나 조금 변형해서 모델링을 수행해 봅시다.

# %%
clear_session()

model = Sequential([
    Conv2D(32, kernel_size=3, input_shape=(150, 150, 1), activation='relu'),
    MaxPooling2D(pool_size=2),
    Conv2D(64, kernel_size=3, activation='relu'),
    MaxPooling2D(pool_size=2),
    Conv2D(128, kernel_size=3, activation='relu'),
    MaxPooling2D(pool_size=2),
    Conv2D(256, kernel_size=3, activation='relu'),
    MaxPooling2D(pool_size=2),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      320
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 512)               6423040
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 6,811,393
# Trainable params: 6,811,393
# Non-trainable params: 0
# _________________________________________________________________

# %%
# GPU 버전에서 약 2 분 소요(GPU를 쓸 수 없다면 20분 이상 소요)
model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy')

history = model.fit(x_train, y_train, epochs = 30, validation_split=0.2).history
# Out:
# Epoch 1/30
# 100/100 [==============================] - 13s 29ms/step - loss: 0.6893 - val_loss: 0.6723
# Epoch 2/30
# 100/100 [==============================] - 3s 27ms/step - loss: 0.6538 - val_loss: 0.6209
# Epoch 3/30
# 100/100 [==============================] - 2s 24ms/step - loss: 0.6039 - val_loss: 0.6076
# Epoch 4/30
# 100/100 [==============================] - 2s 24ms/step - loss: 0.5750 - val_loss: 0.5366
# Epoch 5/30
# 100/100 [==============================] - 3s 26ms/step - loss: 0.5230 - val_loss: 0.6174
# Epoch 6/30
# 100/100 [==============================] - 2s 24ms/step - loss: 0.4870 - val_loss: 0.4861
# Epoch 7/30
# 100/100 [==============================] - 3s 26ms/step - loss: 0.4415 - val_loss: 0.5207
# Epoch 8/30
# 100/100 [==============================] - 2s 25ms/step - loss: 0.4131 - val_loss: 0.6950
# Epoch 9/30
# 100/100 [==============================] - 3s 26ms/step - loss: 0.3901 - val_loss: 0.4526
# Epoch 10/30
# 100/100 [==============================] - 3s 26ms/step - loss: 0.3358 - val_loss: 0.4780
# Epoch 11/30
#  64/100 [==================>...........] - ETA: 0s - loss: 0.3083
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-e61bc3e0adb8> in <module>
#       2 model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy')
#       3
# ----> 4 history = model.fit(x_train, y_train, epochs = 30, validation_split=0.2).history
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1654                             logs = tmp_logs
#    1655                             end_step = step + data_handler.step_increment
# -> 1656                             callbacks.on_train_batch_end(end_step, logs)
#    1657                             if self.stop_training:
#    1658                                 break
#
# /usr/local/lib/python3.9/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     474         """
#     475         if self._should_call_train_batch_hooks:
# --> 476             self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#     477
#     478     def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.9/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     321             self._call_batch_begin_hook(mode, batch, logs)
#     322         elif hook == "end":
# --> 323             self._call_batch_end_hook(mode, batch, logs)
#     324         else:
#     325             raise ValueError(
#
# /usr/local/lib/python3.9/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     344             self._batch_times.append(batch_time)
#     345
# --> 346         self._call_batch_hook_helper(hook_name, batch, logs)
#     347
#     348         if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.9/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     392         for callback in self.callbacks:
#     393             hook = getattr(callback, hook_name)
# --> 394             hook(batch, logs)
#     395
#     396         if self._check_timing:
#
# /usr/local/lib/python3.9/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1092
#    1093     def on_train_batch_end(self, batch, logs=None):
# -> 1094         self._batch_update_progbar(batch, logs)
#    1095
#    1096     def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.9/dist-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1168         if self.verbose == 1:
#    1169             # Only block async when verbose = 1.
# -> 1170             logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1171             self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1172
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     663         return t.item() if np.ndim(t) == 0 else t
#     664
# --> 665     return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     666
#     667
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     915
#     916   return pack_sequence_as(
# --> 917       structure[0], [func(*x) for x in entries],
#     918       expand_composites=expand_composites)
#     919
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     915
#     916   return pack_sequence_as(
# --> 917       structure[0], [func(*x) for x in entries],
#     918       expand_composites=expand_composites)
#     919
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     656         # Don't turn ragged or sparse tensors to NumPy.
#     657         if isinstance(t, tf.Tensor):
# --> 658             t = t.numpy()
#     659         # Strings, ragged and sparse tensors don't have .item(). Return them
#     660         # as-is.
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1153     """
#    1154     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1155     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1156     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1157
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1119   def _numpy(self):
#    1120     try:
# -> 1121       return self._numpy_internal()
#    1122     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1123       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(history)

# %% [markdown]
# * [추가] 만약 학습시간이 너무 오래 걸린다면, 아래 코드로 이미 만든 모델을 로딩합니다.
#     * 로딩하는 모델은 더 많은 데이터로 학습하였습니다.

# %%
model = load_model(path + 'model.h5')

# %% [markdown]
# * 예측 및 평가

# %%
# 예측
pred = model.predict(x_val)
pred = np.where(pred > 0.5, 1, 0)

# 평가
print(f'Accuracy : {accuracy_score(y_val, pred)}')
print('-' * 60)
print('<< Confusion Matrix >>\n')
print(confusion_matrix(y_val, pred))
print('-' * 60)
print(classification_report(y_val, pred))
# Out:
# 63/63 [==============================] - 2s 19ms/step
# Accuracy : 0.9365
# ------------------------------------------------------------
# << Confusion Matrix >>
#
# [[939  70]
#  [ 57 934]]
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.94      1009
#            1       0.93      0.94      0.94       991
#
#     accuracy                           0.94      2000
#    macro avg       0.94      0.94      0.94      2000
# weighted avg       0.94      0.94      0.94      2000

# %% [markdown]
# ## 4.틀린 이미지 찾아보기
# * 아래 코드는 이미지 확인을 위해 실행하는 데에 사용합시다.

# %%
idx = (y_val != pred.reshape(2000,))
x_val_wr = x_val[idx]
y_val_wr = y_val[idx]
pred_wr = pred[idx].reshape(-1,)

x_val_wr = x_val_wr.reshape(-1,150,150)

idx = rd.sample(range(x_val_wr.shape[0]),16)
x_temp = x_val_wr[idx]
y_temp = y_val_wr[idx]
p_temp = pred_wr[idx]
class_name = ['cat','dog']

plt.figure(figsize=(12,12))
for i in range(16):
    plt.subplot(4,4,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(1-x_temp[i], cmap=plt.cm.binary)
    plt.xlabel(f'act : {class_name[y_temp[i]]},  pred : {class_name[p_temp[i]]}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5.인터넷에서 이미지를 찾아 테스트해봅시다.

# %% [markdown]
# ### (1) 이미지 다운받아 구글드라이브에 올리기
# * 인터넷에서 고양이/강아지 이미지 몇 개를 다운 받습니다.
# * 콜랩, 왼쪽 탭 중 파일 선택하고
# * 이미지를 드래그 & 드롭으로 업로드

# %% [markdown]
# ### (2) 이미지 전처리

# %%
# 아래 file_name을 여러분이 업로드한 파일 이름으로 수정합니다.
file_name = '/content/drive/MyDrive/딥러닝/학생용/12.jpg'


# 업로드한 이미지 확인하기
img = cv2.imread(file_name)
print(img.shape)
cv2_imshow(img)
# Out:
# (1024, 1024, 3)
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F42645F2B20>

# %%
# 이미지 전처리
# 흑백으로 다시 로딩
img = cv2.imread(file_name, cv2.IMREAD_GRAYSCALE) 

# 사이즈 조정
img = cv2.resize(img, (150, 150))               # 크기 맞추기
print(img.shape)
cv2_imshow(img)
# Out:
# (150, 150)
# <PIL.Image.Image image mode=L size=150x150 at 0x7F4264607490>

# %%
class_name = ['cat','dog']

# 입력데이터 형식을 갖추기
test_num = img.reshape(1,150,150,1)

# 예측하기(예측된 값이 2차원이어서, 1차원 변환)
pred = model.predict(test_num).reshape(-1,)

# 예측결과 0,1 추출 : pred[0]
# float 타입을 int(정수)로 변환 : int(pred[0])
# class 이름으로 변환 
class_name[int(pred[0])]
# Out:
# 1/1 [==============================] - 0s 236ms/step
# 'dog'
